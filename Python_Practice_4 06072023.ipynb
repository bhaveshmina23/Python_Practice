# %%
# create a function which will take list as a input and give me a final list with all the numeric value

##################################################################################################
def test_1(a):
    n  = []
    for i in a :
        if type(i) == int or type(i) == float :
            n.append(i)
    return n

###################################################################################################

def test_2(a) :
    n = []
    for i in a :
        if type(i) == list :
            for j in i :
                if type(j) == int or type(j) == float :
                    n.append(j)
        else :
            if type(i) == int or type(i) == float :
                n.append(i)
    return n

###################################################################################################


# test_1 function will not count list in a list ,
# test_2 function will count list in a list

# %%
a=[1,2,3,4,"bhavesh","dean",[45,25,3,9]]

print(" test_1 result", test_1(a),"\n","test_2 result", test_2(a))

# %%
#function
def test(p,q):
  return n**p

# lambda function
a = lambda n,p : n**p

# for function - test(3,2)
# for lambda function - a(3,2)

# %%
# lambda function to find maximum of two numbers

max_two = lambda x,y : x if x>y else y

max_two(5,8)

# %%
"""Create a class called "Person" with properties for "name", "age", and "gender".
 Create an object of this class and print out its properties."""

class Person:

  def __init__(self, name, age, gender):
    self.name = name
    self.age = age
    self.gender = gender

person1 = Person("Joe", 30, "male")

print("Name:", person1.name)
print("age:", person1.age)
print("gender", person1.gender)

# %%
"""Write a Python class called "Rectangle" with attributes for "width" and "height".
 Implement methods to calculate the area and perimeter of the rectangle.
 Create an instance of this class and use it to print out the rectangle's area and perimeter"""

class Rectangle:

  def __init__(self, width, height):
    self.width = width
    self.height = height

  def area(self):
    return self.width * self.height

  def perimeter(self):
    return 2*(self.width + self.height)

rect1 = Rectangle(5,9)

print("AREA:", rect1.area())
print("PERIMETER", rect1.perimeter())

# %%
"""Write a Python class called "BankAccount" with attributes for "balance" and "interest_rate".
Implement methods to deposit and withdraw money from the account, as well as to calculate the interest earned on the balance based on the interest rate
 Create an instance of this class and use it to test out the implemented methods for deposit, withdrawal, and interest calculation"""


class BankAccount:

    def __init__(self, balance, interest_rate):
        self.balance = balance
        self.interest_rate = interest_rate

    def deposit(self, amount):
      self.balance += amount

    def withdraw(self, amount):
      self.balance -= amount

    def calculate_interest(self):
      return self.balance * self.interest_rate / 100


account1 = BankAccount(1000, 1.5)

account1.deposit(500)
account1.withdraw(600)

interest_earned = account1.calculate_interest()

print("Balance:", account1.balance)
print("Interest earned:", interest_earned)

# %%
"""Write a Python class called "Animal" with attributes for "name" and "species".
 Create a subclass of "Animal" called "Dog" with additional attributes for "breed" and "owner".
  Implement both classes with appropriate methods and constructors to initialise their properties.
 Create instances of both classes and use them to print out the various properties of the animals and dogs,
  such as their names, species, breeds, and owners"""


class Animal:
  def __init__(self, name, species):
    self.name = name
    self.species = species

class Dog(Animal):
    def __init__(self, name, species, breed, owner):

      super().__init__(name, species)
      self.breed = breed
      self.owner = owner

animal1 = Animal("Tiger", "Feline")

dog1 = Dog("leo", "Canine", "German shepherd", "LALA")

print("Animal name:", animal1.name)
print("Animal species:", animal1.species)

print("Dog name:", dog1.name)
print("Dog species:", dog1.species)
print("Dog breed:", dog1.breed)
print("Dog owner:", dog1.owner)

# %%
"""Create a class called "Car" with properties for "make", "model", and "year".
 Create a subclass of "Car" called "ElectricCar" with additional properties for "battery_size" and "range".
  Create objects of both classes and print out their properties"""

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year


class ElectricCar(Car):
    def __init__(self, make, model, year, battery_size, range):
        super().__init__(make, model, year)
        self.battery_size = battery_size
        self.range = range

car1 = Car("Toyota", "Fortuner", 2019)

electric_car1 = ElectricCar("Tesla", "Model 3", 2021, 75, 263)

print("Car make:", car1.make)
print("Car model:", car1.model)
print("Car year:", car1.year)

print("Electric car make:", electric_car1.make)
print("Electric car model:", electric_car1.model)
print("Electric car year:", electric_car1.year)
print("Electric car battery size:", electric_car1.battery_size)
print("Electric car range:", electric_car1.range)

# %%
"""Create a class called "Student" with properties for "name" and "id".
 Create a subclass of "Student" called "GraduateStudent" with additional properties for "advisor" and "research_area".
  Create objects of both classes and print out their properties"""

class Student:
    def __init__(self, name, id):
        self.name = name
        self.id = id

class GraduateStudent(Student):
    def __init__(self, name, id, advisor, research_area):
        super().__init__(name, id)
        self.advisor = advisor
        self.research_area = research_area


student1 = Student("Shreyan", 12345)

grad_student1 = GraduateStudent("Jay", 67890, "Dr. Aabha", "Computer Science")

print("Student name:", student1.name)
print("Student id:", student1.id)

print("Graduate student name:", grad_student1.name)
print("Graduate student id:", grad_student1.id)
print("Graduate student advisor:", grad_student1.advisor)
print("Graduate student research area:", grad_student1.research_area)

# %%
from re import S
"""Create a class called "Shape" with methods to calculate the area and perimeter of the shape.
 Create subclasses of "Shape" for "Rectangle", "Circle", and "Triangle" with their own methods for calculating area and perimeter.
  Create objects of each class and print out their area and perimeter"""



import math

class Shape:
   def calculate_shape(self):
    pass

   def calculate_area(self):
    pass


class Rectangle(Shape):
  def __init__(self, width, height):
    self.width = width
    self.height = height

  def calculate_area(self):
    return self.width * self.height

  def calculate_perimeter(self):
    return 2*(self.width + self.height)


class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def calculate_area(self):
    return math.pi * self.radius ** 2

  def calculate_perimeter(self):
    return 2* math.pi * self.radius


class Triangle(Shape):
  def __init__(self, a, b, c):
    self.a = a
    self.b = b
    self.c = c

  def calculate_area(self):
    s = (self.a + self.b + self.c) / 2
    return math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))

  def calculate_perimeter(self):
        return self.a + self.b + self.c



rectangle = Rectangle(3, 7)
print("Rectangle area:", rectangle.calculate_area())
print("Rectangle perimeter:", rectangle.calculate_perimeter())

circle = Circle(5)
print("Circle area:", circle.calculate_area())
print("Circle perimeter:", circle.calculate_perimeter())

triangle = Triangle(3, 4, 5)
print("Triangle area:", triangle.calculate_area())
print("Triangle perimeter:", triangle.calculate_perimeter())

# %%
"""Create a class called "Employee" with properties for "name", "id", and "salary".
 Add methods to give the employee a raise and to calculate their annual salary.
  Create objects of this class and test out the methods"""


class Employee:
    def __init__(self, name, id, salary):
        self.name = name
        self.id = id
        self.salary = salary

    def give_raise(self, amount):
        self.salary += amount

    def annual_salary(self):
        return self.salary * 12


employee1 = Employee("Rohit", 12345, 25000)

print("Initial salary:", employee1.salary)

employee1.give_raise(2100)

print("New salary:", employee1.salary)

print("Annual salary:", employee1.annual_salary())

# %%
"""Create a class called "Book" with properties for "title", "author", and "publisher".
 Create a subclass of "Book" called "Ebook" with additional properties for "file_format" and "file_size".
  Create objects of both classes and print out their properties"""

class Book:
    def __init__(self, title, author, publisher):
        self.title = title
        self.author = author
        self.publisher = publisher

class Ebook(Book):
    def __init__(self, title, author, publisher, file_format, file_size):
        super().__init__(title, author, publisher)
        self.file_format = file_format
        self.file_size = file_size

book1 = Book("To Kill a Mockingbird", "Harper Lee", "J. B. Lippincott & Co.")

ebook1 = Ebook("The Hunger Games", "Suzanne Collins", "Scholastic Corporation", "PDF", "2.5 MB")

print("Book title:", book1.title)
print("Book author:", book1.author)
print("Book publisher:", book1.publisher)

print("Ebook title:", ebook1.title)
print("Ebook author:", ebook1.author)
print("Ebook publisher:", ebook1.publisher)
print("Ebook file format:", ebook1.file_format)
print("Ebook file size:", ebook1.file_size)
