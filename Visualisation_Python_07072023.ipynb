# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x, y
# Out:
# (array([0.12693175, 0.58159878, 0.86444271, 0.83085289, 0.88045865,
#         0.73661625, 0.42244107, 0.35749194, 0.59629209, 0.81629062,
#         0.42320751, 0.38043121, 0.68542826, 0.3330856 , 0.16417151,
#         0.47773306, 0.12870142, 0.30929743, 0.07800773, 0.94049945,
#         0.13246892, 0.90797027, 0.5959015 , 0.35013109, 0.19402174,
#         0.39464999, 0.26029854, 0.74570801, 0.23066077, 0.9027527 ,
#         0.0210216 , 0.28325929, 0.40430033, 0.42208255, 0.82932428,
#         0.20967582, 0.97808573, 0.18649654, 0.59467722, 0.68852073,
#         0.81478024, 0.41480942, 0.4492582 , 0.51268462, 0.8881314 ,
#         0.92308435, 0.48083252, 0.16816987, 0.79888114, 0.36702459]),
#  array([0.13607555, 0.53484653, 0.48737939, 0.02973301, 0.77721047,
#         0.7744643 , 0.26794832, 0.04642671, 0.48999921, 0.73586026,
#         0.9175405 , 0.02182455, 0.18864334, 0.54881071, 0.03825418,
#         0.68700979, 0.41546209, 0.53363055, 0.5883398 , 0.17482734,
# ...

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(6,6))

# %%
plt.scatter(x,y,c='purple',alpha=0.9,marker='x')
#c-color, alpha meand transparency as value low , it becomes more fade

# %%
plt.figure(figsize=(6,5))
plt.scatter(x,y,c="red",marker="x",alpha=0.5)
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("hey this is my title")
plt.grid()

# %%
x=np.linspace(1,10,100)  # it makes 1 to 10 in 100 points
y=np.random.rand(100)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,"--k") # "k" is for black colour

# %%
x=['a','b','c','d','e']
y=np.random.rand(5)

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y,color='blue')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y,color='red')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y,color='red')

# %%
data=[1,2,3,2,2,5,4,5,8,7,7]

# %%
plt.hist(data)
plt.savefig("new.png")

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z,c='red',alpha=0.3)
plt.show()

# %%
#Seaborn

import seaborn as sns

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris.sepal_length, y=iris.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris.sepal_length, y=iris.petal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.displot(iris['sepal_length'])

# %%
iris['sepal_length'].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal_length, dtype: int64

# %%
sns.relplot(x=iris.sepal_width,y=iris.sepal_length, data=iris, hue='petal_length')

# %%
sns.relplot(x=iris.sepal_width,y=iris.sepal_length, data=iris, size='petal_length')

# %%
sns.relplot(x=iris.sepal_width,y=iris.sepal_length, data=iris, style='petal_length')

# %%
sns.catplot(x=iris.sepal_width,y=iris.sepal_length, data=iris,)

# %%
sns.jointplot(x=iris.sepal_width,y=iris.sepal_length, data=iris)

# %%
sns.pairplot(iris)

# %%
#Plotly

import plotly.graph_objects as go

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3],y=[3,4,5,5,6,7], mode='markers'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3],y=[3,4,5,5,6,7], mode='lines'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Bar(x=[1,2,3,4,5,3],y=[3,4,5,5,6,7]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Histogram(x=[1,2,3,4,5,3],y=[3,4,5,5,6,7]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Histogram(x=[1,2,3,4,5,3]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3],y=[3,4,5,5,6,7], mode='markers',marker_size=10*x))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=[1,2,3,4,5,3]
y=[3,4,5,5,6,7]
z=[1,2,3,6,8,7]

# %%
fig=go.Figure()
fig.add_trace(go.Scatter3d(x=[1,2,3,4,5,3],
y=[3,4,5,5,6,7],
z=[1,2,3,6,8,7]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter3d(x=[1,2,3,4,5,3],
y=[3,4,5,5,6,7], mode='lines',
z=[1,2,3,6,8,7]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#bokeh

# %%
pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show

# %%
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

# %%
p=figure(title='test_flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_widhth"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="808cd4f7-6fd1-47ab-99ef-952e1f816163" data-root-id="1002"></div>

# %%
p=figure(title='test_flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_widhth"
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="55f48dbb-2348-47e2-8e7f-9866422051af" data-root-id="1222"></div>
